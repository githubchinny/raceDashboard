# %%
import numpy as np
import matplotlib.pyplot as plt

print(np.linspace(1,100,15))

dir = "C:/Users/mark_/McLaren Technology Group/McLaren Accelerator - Sanofi - Sanofi/Data Analysis/"
im = plt.imread(dir + 'chequeredFlag.png')
plt.gca().invert_yaxis()
plt.imshow(im,zorder=1,origin='upper')  
x = np.arange(100)
y = x
t = x

plt.scatter(x, y, c=t, cmap='Oranges',zorder=2)
plt.show()
# Out:
# [  1.           8.07142857  15.14285714  22.21428571  29.28571429
#   36.35714286  43.42857143  50.5         57.57142857  64.64285714
#   71.71428571  78.78571429  85.85714286  92.92857143 100.        ]
